# %%
#1. Skip Number 3
for i in range(1,6):
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
#2. Skip Number 5
for i in range(1,8):
  if i == 5:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7

# %%
#3. Print Odd Numbers Only
for i in range(1,11):
  if i % 2 == 0:
    continue
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#3. Print Odd Numbers Only
for i in range(1,11):
  if i % 2 != 0:
    continue
  print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#skip letter 'a'
word = 'banana'
for ch in word:
  if ch == 'a':
    continue
  print(ch)
# Out:
# b
# n
# n

# %%
#6.skip multiples of 3
for i in range(1,11):
  if i % 3 == 0:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8
# 10

# %%
#7.slip negative numbers
nums = [5,-2,8,-1,10]
for num in nums:
  if num < 0:
    continue
  print(num)
# Out:
# 5
# 8
# 10

# %%
#8. skip spaces in a string
text = ' hello world'
for ch in text:
  if ch == ' ':
    continue
  print(ch,end='')
# Out:
# helloworld

# %%
#9.skip number 2 and 4
for i in range(1,6):
  if i == 2 or i == 4:
    continue
  print(i)
# Out:
# 1
# 3
# 5

# %%
#10.skip numbers gretaer than 5
for i in range(1,11):
  if i >5:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,8):
  if i % 2 == 0:
    continue
  print(i)
# Out:
# 1
# 3
# 5
# 7

# %%
#12. Skip the number 5

#Print numbers from 1 to 10, but skip 5.
for i in range(1,11):
  if i == 5:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
#13. Skip multiples of 4

#Print numbers from 1 to 20, but skip numbers divisible by 4.
for i in range(1,21):
  if i % 4 == 0:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 5
# 6
# 7
# 9
# 10
# 11
# 13
# 14
# 15
# 17
# 18
# 19

# %%
#14. Skip the letter "e"

#Print each character of "elephant" except "e".
word = 'elephant'
for ch in word:
  if ch == 'e':
    continue
  print(ch)
# Out:
# l
# p
# h
# a
# n
# t

# %%
#15.Skip numbers greater than 6

#Print numbers from 1 to 10, but skip numbers greater than 6.
for i in range(1,11):
  if i > 6:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#16. Skip vowels

#Print each character from:

#word = "education"

#but skip vowels (a, e, i, o, u).
word = 'education'
for ch in word:
  if ch in 'aeiou':
    continue
  print(ch)
# Out:
# d
# c
# t
# n

# %%
#17.Skip both 3 and 7

#Print numbers from 1 to 10, but skip 3 and 7.
for i in range(1,11):
  if i == 3 or i == 7:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6
# 8
# 9
# 10
