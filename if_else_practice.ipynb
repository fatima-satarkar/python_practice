# %%
#1.Check whether a number is positive or negative.
num = int(input('Enter number:'))
if num > 0:
  print('Number is positive')
else:
  print('Number is negative')
# Out:
# Enter number:3
# Number is positive

# %%
#2.Check whether a number is even or odd.
num = int(input('Enter number:'))
if num % 2 == 0:
  print('Even number')
else:
  print('Odd number')
# Out:
# Enter number:1
# Odd number

# %%
#3.Check whether a person is eligible to vote (18+).
age = int(input('Enter your age:'))
if age >= 18:
  print('Eligible to vote')
else:
  print('not eligible to vote')
# Out:
# Enter your age:17
# not eligible to vote

# %%
#4.Check whether a number is divisible by 5.
num = int(input('Enter number:'))
if num % 5 == 0:
  print('number is divisible by 5')
else:
  print('number is not divisible by 5')
# Out:
# Enter number:5
# number is divisible by 5

# %%
#5.Check whether a student passed or failed (pass marks = 35).
marks = int(input('Enter marks:'))
if marks >= 35:
  print('Pass')
else:
  print('Fail')
# Out:
# Enter marks:45
# Pass

# %%
#6.Find the greater number between two numbers.
num1 = int(input('Enter first number:'))
num2 = int(input('Enter second number:'))
if num1 > num2 :
  print('first number is greater')
elif num2 > num1:
  print('second number is greater')
else:
    print('both are equal')
# Out:
# Enter first number:2
# Enter second number:2
# both are equal

# %%
#7.Find the smallest number between two numbers.
num1 = int(input('Enter first number:'))
num2 = int(input('Enter second number:'))
if num1 < num2 :
  print('first number is smallest')
elif num2 < num1:
  print('second number is smallest')
else:
    print('both are equal')
# Out:
# Enter first number:1
# Enter second number:1
# both are equal

# %%
#8.Check whether a number is divisible by both 3 and 5.
num = int(input('Enter number:'))
if num % 3 ==0 and num % 5 == 0:
  print('number is divisible by both 3 and 5')
else:
  print('number is not divisible by 3 nd 5')
# Out:
# Enter number:4
# number is not divisible by 3 nd 5

# %%
#9.Check whether a character is a vowel or consonant.
chr = input('Enter character:').lower()
if chr in 'aeiou':
  print('character is vowel')
else:
    print('character is consonant')
# Out:
# Enter character:l
# character is consonant

# %%
#10.Check whether a person is a child, teenager, or adult based on age.
age = int(input('Enter age:'))
if age <= 12:
  print('person is child')
elif age  <= 19:
  print('person is teenager')
else:
  print('person is adult')
# Out:
# Enter age:24
# person is adult

# %%
#11.Find the largest among three numbers.
num1 = int(input('Enter first number:'))
num2 = int(input('Enter second number:'))
num3 = int(input('Enter third number:'))
if num1 > num2 and num1 > num3:
  print('first number is greater')
elif num2 >num1 and num2> num3:
  print('second number is greater')
elif num3 >num1 and num3> num2:
  print('third number is gretaer')
else:
  print('all numbers are equal')
# Out:
# Enter first number:9
# Enter second number:9
# Enter third number:9
# all numbers are equal

# %%
#12.Check whether a year is a leap year.
year =int(input('Enter year:'))
if year % 4 == 0:
  print('Leap year')
else:
  print('not a leap year')
# Out:
# Enter year:2021
# not a leap year

# %%
#13.Create a simple login system:
#correct username and password → Login Successful
#otherwise → Invalid Credentials
user_name = 'admin'
pass_word ='admin123'
username = input('Enter username:')
password =input('Enter password')
if username == user_name and password == pass_word:
  print('login successful')
else:
  print('Wrong credentials! try again')
# Out:
# Enter username:83t8yt
# Enter passwordgfuee
# Wrong credentials! try again

# %%
#14.Check whether a number is a 2-digit, 3-digit, or 4-digit number.
num = int(input('Enter number:'))
if num >= 10 and num  <= 99:
  print('number is two digit')
elif num >= 100 and num <= 999:
  print('number is three digit')
elif num >= 1000 and num<= 9999:
  print('number is four digit ')
else:
  print('number is not 2,3, or 4 digit ')
# Out:
# Enter number:45
# number is two digit

# %%
#15.Create a grade system:
#90+ → A
#75+ → B
#50+ → C
#below 50 → Fail
marks  =int(input('Enter marks:'))
if marks >= 90:
  print('you got A grade')
elif marks >= 75:
  print('You Got B grade')
elif marks >= 50:
  print("You Got C grade")
else:
  print('Fail')
# Out:
# Enter marks:23
# Fail

# %%
#16.Check whether a number is divisible by 2 but not by 3.
num = int(input('Enter number:'))
if num % 2 == 0  and num %3 != 0:
  print('number is divisible by 2 but not by 3')
else:
  print('Number is not divisible by both')
# Out:
# Enter number:5
# Number is not divisible by both

# %%
#17.Check whether a person can enter a movie:
#age >= 18
#ticket = yes
age = int(input('Enter age:'))
if age >= 18:
  print('you can get ticket')
else:
  print('you cannot get a ticket')
# Out:
# Enter age:19
# you can get ticket

# %%
#18.Create a basic ATM withdrawal condition:
#balance must be sufficient
#minimum balance should remain 1000
balance =int(input('Enter balance:'))
withdraw_amount =int(input('Enter withdraw amount'))
if balance - withdraw_amount >= 1000:
  print('withdrawal sucessful')
else:
  print('Innsufficient balance')
# Out:
# Enter balance:5000
# Enter withdraw amount2000
# withdrawal sucessful

# %%
#19.Check whether three angles can form a triangle.
angle1 = int(input('Enter first angle:'))
angle2 = int(input('Enter second angle:'))
angle3 = int(input('Enter third angle:'))
if angle1 + angle2 +angle3 == 180:
  print('Triangle can be formed')
else:
  print('Triangle cannot be formed')
# Out:
# Enter first angle:60
# Enter second angle:60
# Enter third angle:60
# Triangle can be formed

# %%
#20. Find whether the given character is:
#uppercase
#lowercase
#digit
#special character
char = input('Enter a character:')
if char.isupper():
  print('Uppercase')
elif char.islower():
  print('Lowercase')
elif char.isdigit():
  print('digit')
else:
  print('Special character')
# Out:
# Enter a character:^
# Special character
