# %%
#1.Create a function greet() that prints:'Hello world
def greet():
  print('hello world')
greet()
# Out:
# hello world

# %%
#2.Create a function show_name() that prints your name.
def show_name():
  print('fatima')
show_name()
# Out:
# fatima

# %%
#3.Create a function show_age() that prints your age.
def age():
  print(24)
age()
# Out:
# 24

# %%
#4.Create a function addition() that prints the sum of 100 and 200.
def add():
  print(100+200)
add()
# Out:
# 300

# %%
#5.Create a function subtraction() that prints the result of 50 - 20.
def sub():
  print(50-20)
sub()
# Out:
# 30

# %%
#6.Create a function multiplication() that prints the result of 10 × 5.
def mult():
  print(10*5)
mult()
# Out:
# 50

# %%
#7.Create a function division() that prints the result of 100 ÷ 10.
def div():
  print(100 / 10)
div()
# Out:
# 10.0

# %%
#8.Create a function square() that prints the square of 8.
def square():
  print(8*2)
square()
# Out:
# 16

# %%
#9.Create a function cube() that prints the cube of 3.
def cube():
  print(3 ** 3)
cube()
# Out:
# 27

# %%
#10.Create a function city() that prints:
def city():
  print('mumbai')
city()
# Out:
# mumbai

# %%
#11.Create a function country() that prints:
def country():
  print('india')
country()
# Out:
# india

# %%
#12.Create a function language() that prints:
def language():
  print('python')
language()
# Out:
# python

# %%
#13.Create a function stars() that prints:*****
def stars():
  print('**************')
stars()
# Out:
# **************

# %%
#14.

#Create a function numbers() that prints:

#1 2 3 4 5
def num():
  print('1 2 3 4 5')
num()
# Out:
# 1 2 3 4 5

# %%
#15.Create a function even() that prints:True
def even():
  print(10 % 2 == 0)
even()
# Out:
# True

# %%
#16.Create a function odd() that prints:True
def odd():
  print(10 % 2 != 0)
odd()
# Out:
# False

# %%
#17.Create a function message() that prints:I am learning Python
def msg():
  print('I am learning Python')
msg()
# Out:
# I am learning Python

# %%
#18.Create a function fruit() that prints:Mango
def fruit():
  print('mango')
fruit()
# Out:
# mango

# %%
#19.Create a function college() that prints your college name.
def college():
  print('YMIM')
college()
# Out:
# YMIM

# %%
#20.Create a function favorite_color() that prints your favorite color.
def color():
  print('black')
color()
# Out:
# black
